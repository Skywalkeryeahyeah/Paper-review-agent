# %% [markdown]
# backend:

# %%
cd D:\Desktop\paper-review-agent\backend
venv\Scripts\activate
uvicorn main:app --reload --port 8001

# %% [markdown]
# frontend:

# %%
cd D:\Desktop\paper-review-agent\frontend
npm run dev
